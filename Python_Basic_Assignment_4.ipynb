# %% [markdown]
# # 1. What exactly is []?

# %% [raw]
# It is an empty list

# %% [markdown]
# # 2. In a list of values stored in a variable called spam,
# how would you assign the value &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2, 4, 6, 8, 10]
spam[2] = 'hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# # Lets pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %% [markdown]
# # 3. What is the value of spam[int(int('3' * 2) / 11)]?

# %%
spam = ['a', 'b', 'c', 'd']
spam[int(int('3' * 2) / 11)]        #Returns 3rd index i.e. 'd'
# Out:
# 'd'

# %% [markdown]
# # 4. What is the value of spam[-1]?

# %%
spam = ['a', 'b', 'c', 'd']
spam[-1]            #Returns 'd'
# Out:
# 'd'

# %% [markdown]
# # 5. What is the value of spam[:2]?

# %%
spam = ['a', 'b', 'c', 'd']
spam[:2]                           #Returns 'a' and 'b'
# Out:
# ['a', 'b']

# %% [markdown]
# # Let's pretend bacon has the list [3.14, 'cat', 11, 'cat' ,True] for the next three questions.

# %% [markdown]
# # 6. What is the value of bacon.index('cat')?

# %%
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.index('cat')                   #Returns the value of index of first occurence of value
# Out:
# 1

# %% [markdown]
# # 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.append(99)           #Appended 99 at the last of list
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# # 8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.remove('cat')                       # removes the first occurence of 'cat'
bacon
# Out:
# [3.14, 11, 'cat', True]

# %% [markdown]
# # 9. What are the list concatenation and list replication operators?

# %% [raw]
# 1. Operator for list concatenation : +
# 2. Operator for list replication   : *

# %% [markdown]
# # 10. What is difference between the list methods append() and insert()?

# %% [raw]
# 1. In append() function, whatever will be the value placed in round braces, it will be appended
#     at the last position of the list.
# 2. Whereas, in insert() function, we can mention the index and insert the value at defined index

# %% [markdown]
# # 11. What are the two methods for removing items from a list?

# %% [raw]
# 1. remove()
# 2. del
# 3. clear()
# 4. pop()

# %% [markdown]
# # 12. Describe how list values and string values are identical.

# %% [raw]
# Values of list and string are identical as they are having ordered collection of values.
# Both the values can be called by indexing operation.

# %% [markdown]
# # 13. What's the difference between tuples and lists?

# %% [raw]
# 1. List is mutable object whereas tuple is immutable object.
# 2. Tuples are enclosed inside round bracket whereas list is enclosed in square bracket.

# %% [markdown]
# # 14. How do you type a tuple value that only contains the integer 42?

# %%
tuple1 = (42,)
type(tuple1)
# Out:
# tuple

# %% [markdown]
# # 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %%
# By type casting, we can convert tuple into list and list into tuple
# For eg.

list1 = [1,3,6,4,5]
tuple1 = (4,5,6,8,6)

list1 = tuple(list1)      #Coverted list into tuple
tuple1 = list(tuple1)     # Tuple into list

print(type(list1))
print(type(tuple1))
# Out:
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# # 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [raw]
# Arrays

# %% [markdown]
# # 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [raw]
# 1. In case of 1D list, copy.copy() and copy.deepcopy() works same.
# 2. Whereas, in case of 2D list, copy.copy fails whenever changes are made in predefined data.
# 3. In this case, copy.deepcopy works fine in 2D list.
