# %% [markdown]
# # 1. Write a Python program to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# # 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = 4
b = 2
addition = a + b
division = a / b
print(addition)
print(division)
# Out:
# 6
# 2.0

# %% [markdown]
# # 3. Write a Python program to find the area of a triangle?

# %%
#Let's consider triangle having base = 10 cm and height = 15 cm
b = 10
h = 15
area = (1/2)*b*h
print(f"Area of triangle having base {b} cm and height {h} cm is {area} sq. cm")
# Out:
# Area of triangle having base 10 cm and height 15 cm is 75.0 sq. cm

# %% [markdown]
# # 4. Write a Python program to swap two variables?

# %%
a = 10
b = 20
a, b = b, a
print("a =",a)
print("b =",b)
# Out:
# a = 20
# b = 10

# %% [markdown]
# # 5. Write a Python program to generate a random number?

# %%
import random
rand_num = random.random()
print(rand_num)
# Out:
# 0.9527327992838818
